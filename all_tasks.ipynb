# %%
# Graph and Tree Utilities

def compute_vertex_degrees(adj_list):
    degrees = {}
    for node, neighbors in adj_list.items():
        degrees[node] = len(neighbors)
    sorted_degrees = dict(sorted(degrees.items(), key=lambda item: item[1]))
    return sorted_degrees

def adj_list_to_adj_matrix(adj_list):
    nodes = list(adj_list.keys())
    index_map = {node: i for i, node in enumerate(nodes)}
    n = len(nodes)
    matrix = [[0 for _ in range(n)] for _ in range(n)]
    for u in adj_list:
        for v in adj_list[u]:
            i, j = index_map[u], index_map[v]
            matrix[i][j] = 1
    return matrix, nodes

def adj_matrix_to_adj_list(matrix, nodes):
    adj_list = {node: [] for node in nodes}
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] == 1:
                adj_list[nodes[i]].append(nodes[j])
    return adj_list

def check_adjacency(adj_list, node1, node2):
    return node2 in adj_list.get(node1, [])

def is_graph_complete(adj_list):
    total_nodes = len(adj_list)
    for node in adj_list:
        if len(adj_list[node]) != total_nodes - 1:
            return False
    return True

def is_graph_connected(adj_list):
    visited = set()
    def dfs(current):
        visited.add(current)
        for neighbor in adj_list[current]:
            if neighbor not in visited:
                dfs(neighbor)
    starting_node = next(iter(adj_list))
    dfs(starting_node)
    return len(visited) == len(adj_list)

def classify_vertex_sequence(graph, sequence):
    seen_edges = set()
    seen_vertices = set()
    is_path = True
    for i in range(len(sequence) - 1):
        u = sequence[i]
        v = sequence[i + 1]
        if v not in graph.get(u, []):
            return "Not a walk"
        edge = tuple(sorted((u, v)))
        if edge in seen_edges:
            is_path = False
        seen_edges.add(edge)
        if v in seen_vertices:
            is_path = False
        seen_vertices.add(u)
    if is_path:
        return "Path"
    elif len(seen_edges) == len(sequence) - 1:
        return "Trail"
    else:
        return "Walk"

def is_graph_a_tree(adj_list):
    visited = set()
    def dfs(current, parent):
        visited.add(current)
        for neighbor in adj_list[current]:
            if neighbor == parent:
                continue
            if neighbor in visited or not dfs(neighbor, current):
                return False
        return True
    start_node = next(iter(adj_list))
    if not dfs(start_node, None):
        return False
    return len(visited) == len(adj_list)

def generate_spanning_tree(graph):
    tree = {node: [] for node in graph}
    visited = set()
    def dfs(current):
        visited.add(current)
        for neighbor in graph[current]:
            if neighbor not in visited:
                tree[current].append(neighbor)
                tree[neighbor].append(current)
                dfs(neighbor)
    start = next(iter(graph))
    dfs(start)
    return tree

def count_leaf_nodes_in_tree(tree):
    leaf_count = 0
    for node, neighbors in tree.items():
        if len(neighbors) == 1:
            leaf_count += 1
    return leaf_count

def is_binary_tree(tree):
    for node, neighbors in tree.items():
        if len(neighbors) > 3:
            return False
    return True

def get_tree_height(tree, root):
    def dfs(node, parent):
        heights = []
        for child in tree[node]:
            if child != parent:
                heights.append(dfs(child, node))
        return 1 + max(heights, default=0)
    return dfs(root, None)

def get_node_depth(tree, root, target):
    def dfs(node, parent, depth):
        if node == target:
            return depth
        for neighbor in tree[node]:
            if neighbor != parent:
                result = dfs(neighbor, node, depth + 1)
                if result != -1:
                    return result
        return -1
    return dfs(root, None, 0)


# === Example Usage ===

graph = {
    'A': ['B', 'C'],
    'B': ['A', 'C'],
    'C': ['A', 'B', 'D'],
    'D': ['C']
}

tree = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A'],
    'D': ['B'],
    'E': ['B']
}

print("Vertex Degrees:", compute_vertex_degrees(graph))

matrix, nodes = adj_list_to_adj_matrix(graph)
print("Adjacency Matrix:", matrix)
print("Adjacency List from Matrix:", adj_matrix_to_adj_list(matrix, nodes))

print("Are A and B adjacent?", check_adjacency(graph, 'A', 'B'))
print("Is Graph Complete?", is_graph_complete(graph))
print("Is Graph Connected?", is_graph_connected(graph))
print("Sequence Classification:", classify_vertex_sequence(graph, ['A', 'B', 'C', 'D']))
print("Is Graph a Tree?", is_graph_a_tree(graph))

spanning_tree = generate_spanning_tree(graph)
print("Spanning Tree:", spanning_tree)
print("Leaf Nodes in Tree:", count_leaf_nodes_in_tree(tree))
print("Is Binary Tree?", is_binary_tree(tree))
print("Tree Height:", get_tree_height(tree, 'A'))
print("Depth of Node E:", get_node_depth(tree, 'A', 'E'))
# Out:
# Vertex Degrees: {'D': 1, 'A': 2, 'B': 2, 'C': 3}
# Adjacency Matrix: [[0, 1, 1, 0], [1, 0, 1, 0], [1, 1, 0, 1], [0, 0, 1, 0]]
# Adjacency List from Matrix: {'A': ['B', 'C'], 'B': ['A', 'C'], 'C': ['A', 'B', 'D'], 'D': ['C']}
# Are A and B adjacent? True
# Is Graph Complete? False
# Is Graph Connected? True
# Sequence Classification: Path
# Is Graph a Tree? False
# Spanning Tree: {'A': ['B'], 'B': ['A', 'C'], 'C': ['B', 'D'], 'D': ['C']}
# Leaf Nodes in Tree: 3
# Is Binary Tree? True
# Tree Height: 3
# Depth of Node E: 2

# %%
import os
import pandas as pd

# Input and output folder paths
input_folder = "files_cleaned"
output_folder = "Cleaned_Files"

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# List all CSV files in the input folder
csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]

for file_name in csv_files:
    input_path = os.path.join(input_folder, file_name)
    output_path = os.path.join(output_folder, file_name)

    try:
        # Try reading with utf-8, fallback to ISO-8859-1
        try:
            df = pd.read_csv(input_path)
        except UnicodeDecodeError:
            df = pd.read_csv(input_path, encoding='ISO-8859-1')

        # Check for required columns
        if 'First Name' not in df.columns or 'Last Name' not in df.columns:
            raise KeyError("Missing 'First Name' or 'Last Name'")

        # Create full name
        df['Full Name'] = df['First Name'].fillna('') + ' ' + df['Last Name'].fillna('')
        df['Full Name'] = df['Full Name'].str.strip()

        # If 'Company' is missing, create empty column
        if 'Company' not in df.columns:
            df['Company'] = ""

        # Keep only desired columns
        cleaned_df = df[['Full Name', 'Company']]
        cleaned_df = cleaned_df[cleaned_df['Full Name'] != '']  # Remove empty names

        # Save cleaned CSV
        cleaned_df.to_csv(output_path, index=False)
        print(f"✅ Cleaned and saved: {file_name}")

    except Exception as e:
        print(f"❌ Skipping {file_name}: {e}")
# Out:
# ✅ Cleaned and saved: YuvrajSingh_Bhati - Yuvraj Bhati.csv
# ✅ Cleaned and saved: Vishal_Bhardwaj - VISHAL BHARDWAJ.csv
# ✅ Cleaned and saved: khushi_narwariya - Khushi Narwariya.csv
# ✅ Cleaned and saved: Ayush_Kumar - Ayush Kumar.csv
# ✅ Cleaned and saved: Mausam_kumari - Mausam kumari.csv
# ✅ Cleaned and saved: connection1-1 - Aman Adarsh.csv
# ✅ Cleaned and saved: Mohit_Sharma - Mohit Sharma.csv
# ✅ Cleaned and saved: Aman_Singh - Aman Singh.csv
# ✅ Cleaned and saved: Prerana_Rajnag - PRERANA RAJNAG.csv
# ✅ Cleaned and saved: Shivam_Shukla.csv
# ✅ Cleaned and saved: Disha_Sahu - Disha Sahu.csv
# ✅ Cleaned and saved: Challa_Trivedh_Kumar - CHALLA TRIVEDH KUMAR.csv
# ✅ Cleaned and saved: Vinay_Kumar - VINAY KUMAR.csv
# ✅ Cleaned and saved: Divyanshi_Rathour - Divyanshi Rathour.csv
# ✅ Cleaned and saved: Samina_Sultana.csv
# ✅ Cleaned and saved: Arjun Kadam - Arjun Kadam.csv
# ✅ Cleaned and saved: Connections - Aman Verma.csv
# ✅ Cleaned and saved: Linked_in_connection - Samina Sultana.csv
# ✅ Cleaned and saved: Connections - RAVI RAJPUT.csv
# ✅ Cleaned and saved: Anand_Pandey - Anand Pandey.csv
# ✅ Cleaned and saved: Prem kumar.csv
# ✅ Cleaned and saved: Nikhil_Chaurasiya - Nikhil Chaurasiya.csv
# ✅ Cleaned and saved: Ishant_Bhoyar - ISHANT BHOYAR.csv
# ✅ Cleaned and saved: Nirmal LinkdIn Connections - NIRMAL MEWADA.csv
# ✅ Cleaned and saved: Uppara Sai_Maithreyi - UPPARA MAITHREYI.csv
# ✅ Cleaned and saved: Connections - Anand Singh.csv
# ✅ Cleaned and saved: Harisingh_Rajpoot - Harisingh Rajpoot.csv
# ✅ Cleaned and saved: Arun_Singh - ARUN KUMAR.csv
# ✅ Cleaned and saved: Prabhat_Patidar - prabhat patidar.csv
# ✅ Cleaned and saved: Anshu_Kumar - Anshu Kumar.csv
# ✅ Cleaned and saved: Mohd_Monis - Monis.csv
# ✅ Cleaned and saved: Anamika_Kumari - Anamika Kumari.csv
# ✅ Cleaned and saved: Rohit_Malviya - Rohit Malviya.csv
# ✅ Cleaned and saved: Manish_Tiwari - MANISH KUMAR TIWARI.csv
# ✅ Cleaned and saved: Rohit_kumar - ROHIT KUMAR.csv
# ✅ Cleaned and saved: Shivang_Dubey - Shivang Dubey.csv
# ✅ Cleaned and saved: Gaurav_Tiwari - GAURAV TIWARI.csv
# ✅ Cleaned and saved: CHANDAN_GIRI - Chandan Giri.csv
# ✅ Cleaned and saved: Sandeep_kumar - Sandeep Kumar.csv
# ✅ Cleaned and saved: Sarthaksuman_Mishra - Sarthak Mishra.csv
# ✅ Cleaned and saved: Manoj K. Connections - MANOJ KHARKAR - Sheet1.csv
# ✅ Cleaned and saved: Aditya_Singh - Aditya NO-LASTNAME.csv
# ✅ Cleaned and saved: Shubham Kumar - Shubham Kumar.csv
# ✅ Cleaned and saved: Mayank_Raj - Mayank Raj.csv
# ✅ Cleaned and saved: Himanshu_kumar - Himanshu Kumar.csv
# ✅ Cleaned and saved: Shubham_Kang - Shubham Kang.csv
# ✅ Cleaned and saved: Pushpraj_Singh.csv - Pushpraj Singh.csv
# ✅ Cleaned and saved: Ekta Kumari - Ekta Kumari.csv
# ✅ Cleaned and saved: Hiranya_Patil - Hiranya Patil.csv
# ✅ Cleaned and saved: Janu_Chaudhary - Janu Chaudhary.csv
# ✅ Cleaned and saved: Lakhan_Rathore - Lakhan Rathore.csv
# ✅ Cleaned and saved: Aradhya_Patel - Aradhya Patel.csv
# ✅ Cleaned and saved: Connections - Harshit Chaturvedi.csv
# ✅ Cleaned and saved: Chiranjeet_Biswas - Chiranjeet Biswas.csv
# ✅ Cleaned and saved: Pinky_Rana - Pinky Rana.csv
# ✅ Cleaned and saved: ByagariPraveen_Kumar - Byagari Kumar.csv
# ✅ Cleaned and saved: Pawan_Kushwah - Pawan Kushwah.csv
# ✅ Cleaned and saved: Pragati_Chauhan - Pragati Chauhan.csv
# ✅ Cleaned and saved: Ranjeet_Kumar_Yadav - Ranjeet Yadav.csv
# ✅ Cleaned and saved: Bhagwati_Chouhan - Bhagwati NO-LASTNAME.csv
# ✅ Cleaned and saved: HimanshuKanwarChundawat - Himanshu Chundawat.csv
# ✅ Cleaned and saved: Rahul_Kumar_Verma - Rahul Verma.csv
# ✅ Cleaned and saved: Bhaskar_mahato - Bhaskar Mahato.csv
# ✅ Cleaned and saved: Swati_Kumari - Swati kumari.csv
# ✅ Cleaned and saved: Kuldeep_Saraswat - Kuldeep saraswat.csv
# ✅ Cleaned and saved: KARANPAL_SINGH_RANAWAT - KARANPAL SINGH RANAWAT.csv
# ✅ Cleaned and saved: linkedin list - Nidhi Kumari.csv
# ✅ Cleaned and saved: Manoj_Dewda - Manoj Dewda - Sheet1.csv
# ✅ Cleaned and saved: connections - N. Arun Kumar.csv
# ✅ Cleaned and saved: Ajay Jatav Connections-1 - Ajay Jatav.csv
# ✅ Cleaned and saved: Sneha_Shaw.csv
# ✅ Cleaned and saved: Sajan_Kumar - SAJAN KUMAR.csv
# ✅ Cleaned and saved: Vivek_Singh - Vivek Kumar.csv
# ✅ Cleaned and saved: Priya_saini - Priya Saini.csv
# ✅ Cleaned and saved: Sauhard_kumar - Sauhard kumar.csv
# ✅ Cleaned and saved: Shilpi_Shaw - Shilpi Shaw.csv
# ✅ Cleaned and saved: Akanksha_Kushwaha - Akanksha.csv
# ✅ Cleaned and saved: Ajit_Yadav - Ajit Yadav.csv
# ✅ Cleaned and saved: Himanshu_Srivastav - Himanshu Srivastav.csv
# ✅ Cleaned and saved: Ravi_Mourya - Ravi Mourya.csv
# ✅ Cleaned and saved: Ritik_Singh - ritik singh.csv
# ✅ Cleaned and saved: Neeraj_Parmar - NEERAJ PARMAR.csv
# ✅ Cleaned and saved: Anuradha_Tiwari - Anuradha Tiwari.csv
# ✅ Cleaned and saved: Priyadarshi_Kumar - Priyadarshi Kumar.csv
# ✅ Cleaned and saved: Afzal_Raza - Afzl Raza.csv
# ✅ Cleaned and saved: Connections - Ompal Yadav.csv
# ✅ Cleaned and saved: Yuvraj_Chirag - Yuvraj Chirag - Connections.csv
# ✅ Cleaned and saved: Cleaned_Connections - Bhagwan Singh Rawat.csv
# ✅ Cleaned and saved: Naman_Damami - Naman Damami.csv
# ✅ Cleaned and saved: Arpita_Tripathi - Arpita Tripathi.csv
# ✅ Cleaned and saved: Rahul_Kumar - Rahul Kumar.csv
# ✅ Cleaned and saved: Ujjval_Baijal - Ujjval Baijal.csv
# ✅ Cleaned and saved: Aaditya_Raj - Aaditya Raj.csv
# ✅ Cleaned and saved: Sandhya_Kaushal - Sandhya Kaushal.csv
# ✅ Cleaned and saved: Shahid_Ansari - Shahid Ansari.csv
# ✅ Cleaned and saved: Pranjal_Dubey - Pranjal Dubey.csv
# ✅ Cleaned and saved: amit_kumar - Amit Kumar.csv
# ✅ Cleaned and saved: Saurabh_Bisht - Saurabh Bisht.csv
# ✅ Cleaned and saved: Shlok_Gupta - Shlok Gupta.csv
# ✅ Cleaned and saved: Gaurav_Rathore - Gaurav Rathore.csv
# ✅ Cleaned and saved: Ayush_yadav - AYUSH YADAV.csv
# ✅ Cleaned and saved: Vinay_Gupta - VINAY GUPTA.csv
# ✅ Cleaned and saved: Ashwin_Yadav - Ashwin Yadav - Ashwin_Yadav.csv
# ✅ Cleaned and saved: Maneesh_Sakhwar - Maneesh Sakhwar.csv
# ✅ Cleaned and saved: Vivek_kumar - VIVEK KUMAR.csv
# ✅ Cleaned and saved: debangsu_misra.csv - Debangsu Misra.csv
# ✅ Cleaned and saved: Mehtab_Alam - MEHTAB ALAM.csv
# ✅ Cleaned and saved: Connection - VISHAL KUMAR.csv
# ✅ Cleaned and saved: Aman_adarsh-Aman_ Adarsh.csv
# ✅ Cleaned and saved: Suyash_Yadav - Suyash Yadav.csv
# ✅ Cleaned and saved: Dilip_Suthar - DILIP SUTHAR.csv
# ✅ Cleaned and saved: Anoop_Kumar - ANOOP KUMAR.csv
# ✅ Cleaned and saved: Sunny_Kumar - Sunny Kumar.csv
# ✅ Cleaned and saved: Divyanshi_Sahu.csv - Divyanshi Sahu.csv
# ✅ Cleaned and saved: Ramraj_Nagar - Ramraj Nagar.csv
# ✅ Cleaned and saved: JAMAL_AKHTAR - JAMAL AKHTAR.csv
# ✅ Cleaned and saved: Monu_Rajpoot - Monu Rajpoot.csv
# ✅ Cleaned and saved: gaurav_khainwar.csv - Gaurav Khainwar.csv
# ✅ Cleaned and saved: Rani_Kumari - Rani Kumari.csv
# ✅ Cleaned and saved: Sandhya_Parmar - Sandhya Parmar.csv
# ✅ Cleaned and saved: aryan_saini - Aryan Saini.csv
# ✅ Cleaned and saved: Rajiv_Kumar - RAJIV KUMAR.csv
# ✅ Cleaned and saved: Satish_Mahto - Satish Mahto.csv
# ✅ Cleaned and saved: Prachi_Dhakad - PRACHI DHAKAD.csv
# ✅ Cleaned and saved: Abhishek_Singh - Abhishek Singh.csv
# ✅ Cleaned and saved: Alok_raj - Alok Raj.csv
# ✅ Cleaned and saved: Anushri_Mishra - Anushri Mishra.csv
